# %%
qty0ranges=input(0)
price0range=input()

qty0ranges=int(qty0ranges)
price0range=float(price0range)

sum0ranges=qty0ranges*price0range

print("Заплатите", sum0ranges, "руб")
# Out:
# 05
# 200
# Заплатите 1000.0 руб
